# %% [markdown]
# <a href="https://colab.research.google.com/github/monicasofiarestrepo/SimulacionDeSIstemas/blob/main/5_Inventario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def LeadTime():
  dias = [1,2,3]
  probabilidad = [0.6, 0.9, 1]
  rand = random.random()
  for i in range(len(probabilidad)):
    if rand <= probabilidad[i]:
      return dias[i]+1

def Demanda():
  dia = [0,1,2,3,4]
  probi = [0.1, 0.36, 0.71, 0.91, 1]
  randi = random.random()
  for i in range(len(probi)):
    if randi <= probi[i]:
      return dia[i]


M = 11
Pedido= 8
N = 5
inventario = 3
tiempo= 3
defecit = 0

for i in range(30):
  print(f"Pedido: {Pedido}  Inventario: {inventario} Defecit {defecit}")
  print("**************")
  if i %N == 0:
    Pedido = M - inventario + defecit
    lti= LeadTime()
    tiempo = i + LeadTime()
    print(f"tiempo {tiempo}")
  if i == tiempo:
    demandaDia = Demanda()
    inventario += Pedido
  inventario -= demandaDia
  if inventario < 0:
    defecit += abs(inventario)


  print(f"Pedido: {Pedido}  Inventario: {inventario} Defecit {defecit}")
# Out:
# Pedido: 8  Inventario: 3 Defecit 0
# **************
# tiempo 2
# Pedido: 8  Inventario: 2 Defecit 0
# Pedido: 8  Inventario: 2 Defecit 0
# **************
# Pedido: 8  Inventario: 1 Defecit 0
# Pedido: 8  Inventario: 1 Defecit 0
# **************
# Pedido: 8  Inventario: 9 Defecit 0
# Pedido: 8  Inventario: 9 Defecit 0
# **************
# Pedido: 8  Inventario: 9 Defecit 0
# Pedido: 8  Inventario: 9 Defecit 0
# **************
# Pedido: 8  Inventario: 9 Defecit 0
# Pedido: 8  Inventario: 9 Defecit 0
# **************
# tiempo 7
# Pedido: 2  Inventario: 9 Defecit 0
# Pedido: 2  Inventario: 9 Defecit 0
# **************
# Pedido: 2  Inventario: 9 Defecit 0
# Pedido: 2  Inventario: 9 Defecit 0
# **************
# Pedido: 2  Inventario: 9 Defecit 0
# Pedido: 2  Inventario: 9 Defecit 0
# **************
# Pedido: 2  Inventario: 7 Defecit 0
# Pedido: 2  Inventario: 7 Defecit 0
# **************
# Pedido: 2  Inventario: 5 Defecit 0
# Pedido: 2  Inventario: 5 Defecit 0
# **************
# tiempo 14
# Pedido: 6  Inventario: 3 Defecit 0
# Pedido: 6  Inventario: 3 Defecit 0
# **************
# Pedido: 6  Inventario: 1 Defecit 0
# Pedido: 6  Inventario: 1 Defecit 0
# **************
# Pedido: 6  Inventario: -1 Defecit 1
# Pedido: 6  Inventario: -1 Defecit 1
# **************
# Pedido: 6  Inventario: -3 Defecit 4
# Pedido: 6  Inventario: -3 Defecit 4
# **************
# Pedido: 6  Inventario: 1 Defecit 4
# Pedido: 6  Inventario: 1 Defecit 4
# **************
# tiempo 17
# Pedido: 14  Inventario: -1 Defecit 5
# Pedido: 14  Inventario: -1 Defecit 5
# **************
# Pedido: 14  Inventario: -3 Defecit 8
# Pedido: 14  Inventario: -3 Defecit 8
# **************
# Pedido: 14  Inventario: 10 Defecit 8
# Pedido: 14  Inventario: 10 Defecit 8
# **************
# Pedido: 14  Inventario: 9 Defecit 8
# Pedido: 14  Inventario: 9 Defecit 8
# **************
# Pedido: 14  Inventario: 8 Defecit 8
# Pedido: 14  Inventario: 8 Defecit 8
# **************
# tiempo 22
# Pedido: 11  Inventario: 7 Defecit 8
# Pedido: 11  Inventario: 7 Defecit 8
# **************
# Pedido: 11  Inventario: 6 Defecit 8
# Pedido: 11  Inventario: 6 Defecit 8
# **************
# Pedido: 11  Inventario: 16 Defecit 8
# Pedido: 11  Inventario: 16 Defecit 8
# **************
# Pedido: 11  Inventario: 15 Defecit 8
# Pedido: 11  Inventario: 15 Defecit 8
# **************
# Pedido: 11  Inventario: 14 Defecit 8
# Pedido: 11  Inventario: 14 Defecit 8
# **************
# tiempo 27
# Pedido: 5  Inventario: 13 Defecit 8
# Pedido: 5  Inventario: 13 Defecit 8
# **************
# Pedido: 5  Inventario: 12 Defecit 8
# Pedido: 5  Inventario: 12 Defecit 8
# **************
# Pedido: 5  Inventario: 16 Defecit 8
# Pedido: 5  Inventario: 16 Defecit 8
# **************
# Pedido: 5  Inventario: 15 Defecit 8
# Pedido: 5  Inventario: 15 Defecit 8
# **************
# Pedido: 5  Inventario: 14 Defecit 8
